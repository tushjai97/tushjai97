# %% [markdown]
# <a href="https://colab.research.google.com/github/tushjai97/tushjai97/blob/main/Breast_Cancer_detection_with_Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv('breast_cancer.csv')
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y , test_size = 0.2, random_state = 123)


from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
y_predict = classifier.predict(x_test)
print(y_predict)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_predict))

print(np.concatenate((y_predict.reshape(len(y_predict),1), y_test.reshape(len(y_test),1)),1))

from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X= x_train, y = y_train, cv = 10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
# Out:
# [2 2 2 2 2 2 2 2 4 2 2 2 2 2 4 2 2 2 2 4 4 2 4 2 2 2 2 2 4 2 2 4 4 2 2 2 2
#  2 2 2 2 4 2 2 2 4 2 2 4 4 2 4 2 4 2 2 2 2 2 4 2 2 2 4 4 2 4 2 4 2 2 4 4 4
#  2 2 2 2 2 4 2 2 4 2 4 4 2 4 2 4 2 2 4 4 4 2 4 2 2 2 2 2 4 4 2 4 2 4 2 4 2
#  2 4 2 2 4 4 2 2 2 2 2 4 2 4 4 2 2 4 4 2 2 4 4 2 4 4]
# 0.9854014598540146
# [[88  2]
#  [ 0 47]]
# [[2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [4 4]
#  [2 2]
#  [2 2]
#  [4 4]
#  [4 4]
#  [4 4]
# ...
